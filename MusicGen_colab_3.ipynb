# %% [markdown]
# <a href="https://colab.research.google.com/github/Marpink/Marpink.github.io/blob/master/MusicGen_colab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 更新 apt 并安装 Python 3.10
# !sudo apt-get update -y
# !sudo apt-get install -y python3.10 python3.10-dev python3.10-distutils

# 2. 把 Python 3.10 注册到 alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 2

# 3. 切换默认 Python 为 3.10（会弹出选择界面，输入对应编号）
# !sudo update-alternatives --config python3

# %%
# 检查版本
# !python --version
# !python3 --version

# 修复 pip
# !sudo apt-get install -y python3-pip
# !python -m pip install --upgrade pip

# %%
# %cd /content
# !git clone -b v1.0 https://github.com/camenduru/audiocraft
# %cd /content/audiocraft
# !pip install -r requirements.txt
# !python app.py --share

# %cd /content

# 重新克隆（干净环境更好）
# !rm -rf audiocraft
# !git clone -b v1.0 https://github.com/camenduru/audiocraft
# %cd /content/audiocraft

# !apt-get update && apt-get install -y ffmpeg

# 升级基础工具
# !pip install -U pip setuptools wheel

# 先安装 requirements.txt（允许失败继续）
# !pip install -r requirements.txt --no-build-isolation || echo "部分包安装失败，继续手动修复..."

# 重点修复常见问题包
# !pip install av --no-deps
# !pip install spacy==3.5.2 --no-build-isolation --no-deps

# 安装 audiocraft 本体
# !pip install -e .

# === 修复 TorchCodec 错误 ===
# !pip install torchcodec -q

# 或者如果上面安装失败，用这个兼容版本
# !pip install torchcodec==0.7.* -q

import torchaudio
print("✅ TorchCodec installed!")
# print("Available backends:", torchaudio.list_audio_backends())

# # === 最重要的 matplotlib 修复 ===
# !pip install matplotlib-inline --upgrade
# import os
# os.environ['MPLBACKEND'] = 'Agg'
# import matplotlib
# matplotlib.use('Agg')

# print("✅ 环境修复完成！")

# 启动
# !python app.py --share

# %%
# === 最重要的 matplotlib 修复 ===
# !pip install matplotlib-inline --upgrade
import os
os.environ['MPLBACKEND'] = 'Agg'
import matplotlib
matplotlib.use('Agg')

print("✅ 环境修复完成！")

启动
# !python app.py --share
